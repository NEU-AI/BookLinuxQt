# %% [markdown]
# # 项目1：实时时钟显示
#
# 主窗体、标签、对话框、定时器、实时时钟、信号与槽机制、
#
# # 项目2：按钮+图片显示
#
# 按钮使用、显示不同png小图标
#
# # 项目3：数据采集与显示
#
# 通过串口接收数据并在标签中显示
#
# # 项目4：Layout变更界面风格
#
# 使用layout完成界面绘制
#
# # 项目5：绘图
#
# 画国旗
#
# # 项目6：波形绘制
#
# 使用虚拟数据完成心电波形绘制
